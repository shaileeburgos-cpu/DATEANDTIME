# %%
from datetime import datetime, timedelta, date

now = datetime.now()
today = date.today()
week_later = today + timedelta(days=7)

now, today, week_later
# Out:
# (datetime.datetime(2026, 4, 29, 10, 31, 6, 62886),
#  datetime.date(2026, 4, 29),
#  datetime.date(2026, 5, 6))

# %% [markdown]
# DATE AND TIME OVERVIEW

# %%
import datetime

# %%
lastweek = (2026, 4, 22)

print(lastweek)
# Out:
# (2026, 4, 22)
